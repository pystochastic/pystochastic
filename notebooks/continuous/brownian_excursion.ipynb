# %%
import numpy as np
import plotly.graph_objs as go

# %%
from pystochastic.processes.continuous import BrownianExcursion as TestType
from stochastic.continuous import BrownianExcursion as StochasticTestType

# %%
seed = 1234567890
n = 10
t = 1

rng = np.random.default_rng(seed)
np.random.seed(seed)

# %%
x = TestType(t=t, rng=rng)
xs = x.sample(n=n)

y = StochasticTestType(t=t)
ys = y.sample(n=n)

# %%
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        y=xs,
        mode="lines",
        name="Current",
    )
)

fig.add_trace(
    go.Scatter(
        y=ys,
        mode="lines",
        name="Original",
    )
)


fig.update_layout(
    title="Samples",
    xaxis_title="Sample Index",
    yaxis_title="Amplitude",
)

fig.show()

# %%
display(xs, ys)
# Out:
# array([0.        , 0.2960961 , 0.52455504, 0.65125082, 0.52747872,
#        0.7465818 , 0.70894499, 0.7502227 , 0.14552026, 0.191481  ,
#        0.        ])
# array([0.        , 0.14596074, 0.05447974, 0.45057584, 0.77903478,
#        1.00573056, 0.98195846, 1.30106154, 1.36342473, 0.50470244,
#        0.        ])
