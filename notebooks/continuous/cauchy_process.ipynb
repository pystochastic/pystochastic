# %%
import numpy as np
import plotly.graph_objs as go

# %%
from pystochastic.processes.continuous import CauchyProcess as TestType
from stochastic.continuous import CauchyProcess as StochasticTestType

# %%
seed = 1234567890
n = 10
t = 1

rng = np.random.default_rng(seed)
np.random.seed(seed)

# %%
x = TestType(t=t, rng=rng)
xs = x.sample(n=n)

y = StochasticTestType(t=t)
ys = y.sample(n=n)
# Out:
# delta_t: 0.1
# times: [0.03555805 0.03770377 0.05566753 0.11935359 0.19168256 0.19256947
#  0.65121185 0.66627497 0.68102287 0.69205682]
# delta_t: 0.1
# times: [2.01967037e-02 3.75689257e-02 2.92779849e-01 5.62273307e-01
#  5.71333930e-01 6.34350495e-01 6.38409705e-01 2.10582048e+02
#  2.10595369e+02 2.10608521e+02]

# %%
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        y=xs,
        mode="lines",
        name="Current",
    )
)

fig.add_trace(
    go.Scatter(
        y=ys,
        mode="lines",
        name="Original",
    )
)


fig.update_layout(
    title="Samples",
    xaxis_title="Sample Index",
    yaxis_title="Amplitude",
)

fig.show()

# %%
display(xs, ys)
# Out:
# array([ 0.        , -0.26731955, -0.27224655, -0.31180139, -0.27035921,
#        -0.48027435, -0.49948711,  1.06182906,  1.09786321,  1.11243304,
#         1.27529449])
# array([ 0.        , -0.28981919, -0.28741371, -0.65751467, -0.23741173,
#        -0.18074097, -0.11206965, -0.14510377,  8.05264965,  8.02424531,
#         8.02463999])
